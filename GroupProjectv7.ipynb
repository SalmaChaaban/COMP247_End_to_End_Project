X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20240317T113252Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAYZTTEKKEQQ4EH4NX%2F20240317%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=8025178d57ab0243c10bffa9d670b290b2e9f21811c13dd494d2d4e128afdb33'> Toronto Police KSI Glossary </a>
#     </body>
# </div>

# %% [markdown]
# <div style="background-color: #FFD1DC; color: black; padding: 10px;">
#     <h4 style="text-align: center;"><b>IMPORTS</b></h4>
# </div>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency

# %% [markdown]
# <div style="background-color: #FFD1DC; color: black; padding: 10px;">
#     <h4 style="text-align: center;"><b>VISUAL AIDS</b></h4>
# </div>

# %%
pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', 60)

# %%
class Colors:
    BLUE = '\033[94m' + '\033[1m'
    MAUVE = '\033[95m' + '\033[1m' + '\033[4m'
    RED = '\033[91m' + '\033[1m' + '\033[4m'
    GREEN = '\033[92m' + '\033[1m' + '\033[4m'
    END = '\033[0m'

# %% [markdown]
# <div style="background-color: #FFD1DC; color: black; padding: 10px;">
#     <h4 style="text-align: center;"><b>PRELIMINARY DATA EXPLORATION AND CLEANING</b></h4>
# </div>

# %% [markdown]
# <h3 style="color:maroon;">Read from csv file</h3>

# %%
# # Read data frame
try:
    df = pd.read_csv(r"G:\My Drive\Colab Notebooks\KSI.csv")
except:
    df = pd.read_csv('KSI.csv')

# %% [markdown]
# <h3 style="color:maroon;">Function to explore basic properties of dataframe</h3>

# %%
# Function to summarize dataframe info
def df_info(df):
    info = pd.DataFrame({'Type':df.dtypes})
    isnull = pd.DataFrame({'# IsNull':df.isnull().sum()})
    notnull = pd.DataFrame({'# NotNull' : df.count()})
    total = pd.DataFrame({'# Total': df.isnull().sum() + df.count()})
    percent_missing = pd.DataFrame({'% Missing': (df.isnull().sum() / df.shape[0]) *100})
    nunique = pd.DataFrame({'# Unique': df.nunique()})
    percent_unique = pd.DataFrame({'% Unique': (df.nunique() / df.shape[0]) *100})
    df_summary = pd.concat([info,isnull,notnull,total,nunique,percent_unique,percent_missing], axis=1)

    print(Colors.BLUE + 'Shape of dataframe:' +  Colors.END)
    print(df.shape)

    return df_summary

# Function to summarize column info
def column_info(df, columns):
    for column in columns:
        print(Colors.BLUE + f'Column: {column}' +  Colors.END)
        print(f'Percentage missing values: {(df[column].isnull().sum()/df.shape[0])*100}')
        print(f'Number of unique values: {df[column].nunique()}')
        print(f'Unique values: {df[column].unique()}')
        print("")

    return None

# %% [markdown]
# <h3 style="color:maroon;">Properties of original dataframe</h3>

# %%
print(Colors.MAUVE + 'Head of dataframe:' +  Colors.END)
df.head()
# Out:
# Head of dataframe:
#               X             Y   INDEX_    ACCNUM  YEAR  \
# 0 -8.844611e+06  5.412414e+06  3387730  892658.0  2006
# 1 -8.844611e+06  5.412414e+06  3387731  892658.0  2006
# 2 -8.816480e+06  5.434843e+06  3388101  892810.0  2006
# 3 -8.829728e+06  5.419071e+06  3389067  893184.0  2006
# 4 -8.816480e+06  5.434843e+06  3388102  892810.0  2006
#
#                      DATE  TIME          STREET1         STREET2 OFFSET  ...  \
# 0  2006/03/11 05:00:00+00   852       BLOOR ST W     DUNDAS ST W    NaN  ...
# 1  2006/03/11 05:00:00+00   852       BLOOR ST W     DUNDAS ST W    NaN  ...
# 2  2006/03/11 05:00:00+00   915  MORNINGSIDE AVE  SHEPPARD AVE E    NaN  ...
# 3  2006/01/01 05:00:00+00   236     WOODBINE AVE     O CONNOR DR    NaN  ...
# 4  2006/03/11 05:00:00+00   915  MORNINGSIDE AVE  SHEPPARD AVE E    NaN  ...
#
#   AG_DRIV REDLIGHT  ALCOHOL  DISABILITY  HOOD_158 NEIGHBOURHOOD_158 HOOD_140  \
# 0     Yes      NaN      NaN         NaN        88   High Park North       88
# 1     Yes      NaN      NaN         NaN        88   High Park North       88
# 2     Yes      Yes      NaN         NaN       146      Malvern East      132
# 3     Yes      NaN      Yes         NaN        60  Woodbine-Lumsden       60
# 4     Yes      Yes      NaN         NaN       146      Malvern East      132
#
#        NEIGHBOURHOOD_140 DIVISION ObjectId
# 0   High Park North (88)      D11        1
# 1   High Park North (88)      D11        2
# 2          Malvern (132)      D42        3
# 3  Woodbine-Lumsden (60)      D55        4
# 4          Malvern (132)      D42        5
#
# [5 rows x 57 columns]

# %%
print(Colors.MAUVE + 'Summary of numerical values:' +  Colors.END)
df.describe()
# Out:
# Summary of numerical values:
#                   X             Y        INDEX_        ACCNUM          YEAR  \
# count  1.819400e+04  1.819400e+04  1.819400e+04  1.326400e+04  18194.000000
# mean  -8.838345e+06  5.420748e+06  3.818870e+07  4.248444e+08   2012.934869
# std    1.162533e+04  8.682160e+03  3.726463e+07  1.065503e+09      4.754258
# min   -8.865305e+06  5.402162e+06  3.363207e+06  2.530100e+04   2006.000000
# 25%   -8.846591e+06  5.413242e+06  5.391370e+06  1.021229e+06   2009.000000
# 50%   -8.838448e+06  5.419556e+06  7.644612e+06  1.197308e+06   2012.000000
# 75%   -8.829671e+06  5.427813e+06  8.078261e+07  1.365020e+06   2017.000000
# max   -8.807929e+06  5.443099e+06  8.170606e+07  4.008024e+09   2022.000000
#
#                TIME       WARDNUM      LATITUDE     LONGITUDE    FATAL_NO  \
# count  18194.000000  1.733200e+04  18194.000000  18194.000000  827.000000
# mean    1362.615917  2.521028e+03     43.710459    -79.396201   29.073761
# std      630.816048  1.844803e+05      0.056369      0.104432   17.803627
# min        0.000000  1.000000e+00     43.589678    -79.638390    1.000000
# 25%      920.000000  7.000000e+00     43.661727    -79.470280   14.000000
# 50%     1450.000000  1.300000e+01     43.702745    -79.397132   28.000000
# 75%     1850.000000  2.200000e+01     43.756345    -79.318286   42.000000
# max     2359.000000  1.716222e+07     43.855445    -79.122974   78.000000
#
#            ObjectId
# count  18194.000000
# mean    9097.500000
# std     5252.299734
# min        1.000000
# 25%     4549.250000
# 50%     9097.500000
# 75%    13645.750000
# max    18194.000000

# %%
df.hist(bins=50,figsize=(15,10), color='orange', alpha=0.75)
plt.show()

# %%
print(Colors.MAUVE + 'Properties of original dataframe:' +  Colors.END)
df_info(df)
# Out:
# Properties of original dataframe:
# Shape of dataframe:
# (18194, 57)
#                       Type  # IsNull  # NotNull  # Total  # Unique  \
# X                  float64         0      18194    18194      4937
# Y                  float64         0      18194    18194      4500
# INDEX_               int64         0      18194    18194     18194
# ACCNUM             float64      4930      13264    18194      4629
# YEAR                 int64         0      18194    18194        17
# DATE                object         0      18194    18194      3925
# TIME                 int64         0      18194    18194      1329
# STREET1             object         0      18194    18194      1856
# STREET2             object      1684      16510    18194      2704
# OFFSET              object     14792       3402    18194       477
# ROAD_CLASS          object       376      17818    18194        10
# DISTRICT            object       105      18089    18194         5
# WARDNUM            float64       862      17332    18194        71
# LATITUDE           float64         0      18194    18194      4500
# LONGITUDE          float64         0      18194    18194      4937
# LOCCOORD            object        95      18099    18194         7
# ACCLOC              object      5450      12744    18194         9
# TRAFFCTL            object        34      18160    18194        10
# VISIBILITY          object        20      18174    18194         8
# LIGHT               object         0      18194    18194         9
# RDSFCOND            object        25      18169    18194         9
# ACCLASS             object         5      18189    18194         3
# IMPACTYPE           object         4      18190    18194        10
# INVTYPE             object        16      18178    18194        19
# INVAGE              object         0      18194    18194        21
# INJURY              object      1611      16583    18194         5
# FATAL_NO           float64     17367        827    18194        78
# INITDIR             object      5052      13142    18194         5
# VEHTYPE             object      3228      14966    18194        31
# MANOEUVER           object      7660      10534    18194        16
# DRIVACT             object      8951       9243    18194        13
# DRIVCOND            object      8954       9240    18194        10
# PEDTYPE             object     15134       3060    18194        16
# PEDACT              object     15112       3082    18194        15
# PEDCOND             object     15110       3084    18194        10
# CYCLISTYPE          object     17420        774    18194        22
# CYCACT              object     17428        766    18194        11
# CYCCOND             object     17429        765    18194        10
# PEDESTRIAN          object     10840       7354    18194         1
# CYCLIST             object     16288       1906    18194         1
# AUTOMOBILE          object      1644      16550    18194         1
# MOTORCYCLE          object     16607       1587    18194         1
# TRUCK               object     17072       1122    18194         1
# TRSN_CITY_VEH       object     17084       1110    18194         1
# EMERG_VEH           object     18151         43    18194         1
# PASSENGER           object     11288       6906    18194         1
# SPEEDING            object     15619       2575    18194         1
# AG_DRIV             object      8734       9460    18194         1
# REDLIGHT            object     16674       1520    18194         1
# ALCOHOL             object     17406        788    18194         1
# DISABILITY          object     17708        486    18194         1
# HOOD_158            object         0      18194    18194       159
# NEIGHBOURHOOD_158   object         0      18194    18194       159
# HOOD_140            object         0      18194    18194       141
# NEIGHBOURHOOD_140   object         0      18194    18194       141
# DIVISION            object         0      18194    18194        17
# ObjectId             int64         0      18194    18194     18194
#
#                      % Unique  % Missing
# X                   27.135319   0.000000
# Y                   24.733429   0.000000
# INDEX_             100.000000   0.000000
# ACCNUM              25.442454  27.096845
# YEAR                 0.093437   0.000000
# DATE                21.573046   0.000000
# TIME                 7.304606   0.000000
# STREET1             10.201165   0.000000
# STREET2             14.862042   9.255799
# OFFSET               2.621743  81.301528
# ROAD_CLASS           0.054963   2.066615
# DISTRICT             0.027482   0.577113
# WARDNUM              0.390239   4.737826
# LATITUDE            24.733429   0.000000
# LONGITUDE           27.135319   0.000000
# LOCCOORD             0.038474   0.522150
# ACCLOC               0.049467  29.954930
# TRAFFCTL             0.054963   0.186875
# VISIBILITY           0.043971   0.109926
# LIGHT                0.049467   0.000000
# RDSFCOND             0.049467   0.137408
# ACCLASS              0.016489   0.027482
# IMPACTYPE            0.054963   0.021985
# INVTYPE              0.104430   0.087941
# INVAGE               0.115423   0.000000
# INJURY               0.027482   8.854567
# FATAL_NO             0.428713  95.454545
# INITDIR              0.027482  27.767396
# VEHTYPE              0.170386  17.742113
# MANOEUVER            0.087941  42.101792
# DRIVACT              0.071452  49.197538
# DRIVCOND             0.054963  49.214027
# PEDTYPE              0.087941  83.181269
# PEDACT               0.082445  83.060350
# PEDCOND              0.054963  83.049357
# CYCLISTYPE           0.120919  95.745850
# CYCACT               0.060459  95.789821
# CYCCOND              0.054963  95.795317
# PEDESTRIAN           0.005496  59.580081
# CYCLIST              0.005496  89.524019
# AUTOMOBILE           0.005496   9.035946
# MOTORCYCLE           0.005496  91.277344
# TRUCK                0.005496  93.833132
# TRSN_CITY_VEH        0.005496  93.899088
# EMERG_VEH            0.005496  99.763658
# PASSENGER            0.005496  62.042432
# SPEEDING             0.005496  85.846983
# AG_DRIV              0.005496  48.004837
# REDLIGHT             0.005496  91.645597
# ALCOHOL              0.005496  95.668902
# DISABILITY           0.005496  97.328790
# HOOD_158             0.873914   0.000000
# NEIGHBOURHOOD_158    0.873914   0.000000
# HOOD_140             0.774981   0.000000
# NEIGHBOURHOOD_140    0.774981   0.000000
# DIVISION             0.093437   0.000000
# ObjectId           100.000000   0.000000

# %% [markdown]
# <div style="background-color: rgba(120,120,200,0.25); padding: 10px;">
#     <h5>Key observations<br></h5>
#     <body>
#         <ul>
#             <li>All values in fields <b>ObjectID</b> and <b>INDEX_</b> are unique.</li>
#             <li>Consequently these fields will be dropped from the dataframe.</li>
#             <li>0.027% of the values of the target column (<b>ACCLASS</b>) are missing. These rows will be dropped.</li>
#         </ul>
#     </body>
# </div>

# %% [markdown]
# <h3 style="color:maroon;">Drop columns <b>ObjectID</b> and <b>INDEX_</b></h3>

# %%
#Drop irrelevant columns which are unique identifier eg: ['ObjectId','INDEX_']
columns_to_drop = ['ObjectId', 'INDEX_']
df = df.drop(columns=columns_to_drop)

print(Colors.MAUVE + 'Properties of dataframe after dropping the columns:' +  Colors.END)
df_info(df)
# Out:
# Properties of dataframe after dropping the columns:
# Shape of dataframe:
# (18194, 55)
#                       Type  # IsNull  # NotNull  # Total  # Unique   % Unique  \
# X                  float64         0      18194    18194      4937  27.135319
# Y                  float64         0      18194    18194      4500  24.733429
# ACCNUM             float64      4930      13264    18194      4629  25.442454
# YEAR                 int64         0      18194    18194        17   0.093437
# DATE                object         0      18194    18194      3925  21.573046
# TIME                 int64         0      18194    18194      1329   7.304606
# STREET1             object         0      18194    18194      1856  10.201165
# LIGHT               0.000000
# RDSFCOND            0.137408
# ACCLASS             0.027482
# IMPACTYPE           0.021985
# INVTYPE             0.087941
# INVAGE              0.000000
# INJURY              8.854567
# FATAL_NO           95.454545
# INITDIR            27.767396
# VEHTYPE            17.742113
# MANOEUVER          42.101792
# DRIVACT            49.197538
# DRIVCOND           49.214027
# PEDTYPE            83.181269
# PEDACT             83.060350
# PEDCOND            83.049357
# CYCLISTYPE         95.745850
# CYCACT             95.789821
# CYCCOND            95.795317
# PEDESTRIAN         59.580081
# CYCLIST            89.524019
# AUTOMOBILE          9.035946
# MOTORCYCLE         91.277344
# TRUCK              93.833132
# TRSN_CITY_VEH      93.899088
# EMERG_VEH          99.763658
# PASSENGER          62.042432
# SPEEDING           85.846983
# AG_DRIV            48.004837
# REDLIGHT           91.645597
# ALCOHOL            95.668902
# DISABILITY         97.328790
# HOOD_158            0.000000
# NEIGHBOURHOOD_158   0.000000
# HOOD_140            0.000000
# NEIGHBOURHOOD_140   0.000000
# DIVISION            0.000000

# %% [markdown]
# <h3 style="color:maroon;">Drop rows with values missing in <b>ACCLASS</b></h3>

# %%
print(Colors.MAUVE + 'ACCLASS info before dropping rows with missing values:' +  Colors.END)
column_info(df,['ACCLASS'])

df.dropna(subset=['ACCLASS'], inplace=True)

print(Colors.MAUVE + 'ACCLASS info after dropping rows with missing values:' +  Colors.END)
column_info(df,['ACCLASS'])

print(Colors.MAUVE + 'Shape of dataframe after dropping rows with missing ACCLASS values:' +  Colors.END)
print(df.shape)
# Out:
# ACCLASS info before dropping rows with missing values:
# Column: ACCLASS
# Percentage missing values: 0.027481587336484554
# Number of unique values: 3
# Unique values: ['Fatal' 'Non-Fatal Injury' 'Property Damage Only' nan]
#
# ACCLASS info after dropping rows with missing values:
# Column: ACCLASS
# Percentage missing values: 0.0
# Number of unique values: 3
# Unique values: ['Fatal' 'Non-Fatal Injury' 'Property Damage Only']
#
# Shape of dataframe after dropping rows with missing ACCLASS values:
# (18189, 55)

# %% [markdown]
# <h3 style="color:maroon;">Determine binary columns</h3>

# %%
# Function to find binary columns ie.columns with yes or naan
def find_binary_columns(df):
    binary_columns = []
    for column in df.columns:
        unique_values = df[column].unique()
        if len(unique_values) == 2:
            binary_columns.append(column)
    return binary_columns

# %% [markdown]
# <h3 style="color:maroon;">Examine binary columns</h3>

# %%
# search and examine binary columns in dataframe
binary_columns = find_binary_columns(df)

print(Colors.MAUVE + 'Names of binary columns:' +  Colors.END)
print(binary_columns)

print(Colors.RED + '-'*100 + Colors.END)

# print(Colors.MAUVE + 'Values of binary colums:' +  Colors.END)
# for column in binary_columns:
#     print(f'{column} : {df[column].unique()}')

column_info(df,binary_columns)

print(Colors.RED + '-'*100 + Colors.END)

print(Colors.MAUVE + 'Binary column head:' +  Colors.END)
df[binary_columns].head()
# Out:
# Names of binary columns:
# ['PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE', 'TRUCK', 'TRSN_CITY_VEH', 'EMERG_VEH', 'PASSENGER', 'SPEEDING', 'AG_DRIV', 'REDLIGHT', 'ALCOHOL', 'DISABILITY']
# ----------------------------------------------------------------------------------------------------
# Column: PEDESTRIAN
# Percentage missing values: 59.59645939853758
# Number of unique values: 1
# Unique values: ['Yes' nan]
#
# Column: CYCLIST
# Percentage missing values: 89.52113915003574
# Number of unique values: 1
# Unique values: [nan 'Yes']
#
# Column: AUTOMOBILE
# Percentage missing values: 9.038429820221012
# Number of unique values: 1
# Unique values: ['Yes' nan]
#
# Column: MOTORCYCLE
# Percentage missing values: 91.2749463961735
# Number of unique values: 1
# Unique values: [nan 'Yes']
#
# Column: TRUCK
# Percentage missing values: 93.83143658254988
# Number of unique values: 1
# Unique values: [nan 'Yes']
#
# Column: TRSN_CITY_VEH
# Percentage missing values: 93.89741052284347
# Number of unique values: 1
# Unique values: [nan 'Yes']
#
# Column: EMERG_VEH
# Percentage missing values: 99.76359338061465
# Number of unique values: 1
# Unique values: [nan 'Yes']
#
# Column: PASSENGER
# Percentage missing values: 62.04849084611579
# Number of unique values: 1
# Unique values: [nan 'Yes']
#
# Column: SPEEDING
# Percentage missing values: 85.84309197866843
# Number of unique values: 1
# Unique values: [nan 'Yes']
#
# Column: AG_DRIV
# Percentage missing values: 47.99054373522459
# Number of unique values: 1
# Unique values: ['Yes' nan]
#
# Column: REDLIGHT
# Percentage missing values: 91.64330089614602
# Number of unique values: 1
# Unique values: [nan 'Yes']
#
# Column: ALCOHOL
# Percentage missing values: 95.66771125405464
# Number of unique values: 1
# Unique values: [nan 'Yes']
#
# Column: DISABILITY
# Percentage missing values: 97.32805541810986
# Number of unique values: 1
# Unique values: [nan 'Yes']
#
# ----------------------------------------------------------------------------------------------------
# Binary column head:
#   PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK TRSN_CITY_VEH EMERG_VEH  \
# 0        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 1        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 2        NaN     NaN        Yes        Yes   NaN           NaN       NaN
# 3        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 4        NaN     NaN        Yes        Yes   NaN           NaN       NaN
#
#   PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL DISABILITY
# 0       NaN      NaN     Yes      NaN     NaN        NaN
# 1       NaN      NaN     Yes      NaN     NaN        NaN
# 2       NaN      NaN     Yes      Yes     NaN        NaN
# 3       Yes      Yes     Yes      NaN     Yes        NaN
# 4       NaN      NaN     Yes      Yes     NaN        NaN

# %% [markdown]
# <div style="background-color: rgba(120,120,200,0.25); padding: 10px;">
#     <h5>Analysis of binary columns<br></h5>
#     <body>
#         <ul>
#             <li>If a condition in a binary column is present, it is marked with <b>Yes</b>.</li>
#             <li>If a condition in a binary column is absent, it is marked with <b>NaN</b>.</li>
#             <li>To distinguish between absent conditions and missing values wee substitute <b>NaN</b> by <b>No</b> for absent conditions.</li>
#         </ul>
#     </body>
# </div>

# %% [markdown]
# <h3 style="color:maroon;">Substitute <b>NaN</b> by <b>No</b> in binary columns</h3>

# %%
df[binary_columns] = df[binary_columns].fillna('No')

# %% [markdown]
# <h3 style="color:maroon;">Re-check binary columns</h3>

# %%
print(Colors.MAUVE + 'Values of binary colums:' +  Colors.END)
# for column in binary_columns:
#     print(f'{column} : {df[column].unique()}')
column_info(df,binary_columns)

print(Colors.RED + '-'*100 + Colors.END)

print(Colors.MAUVE + 'Binary column head:' +  Colors.END)
df[binary_columns].head()
# Out:
# Values of binary colums:
# Column: PEDESTRIAN
# Percentage missing values: 0.0
# Number of unique values: 2
# Unique values: ['Yes' 'No']
#
# Column: CYCLIST
# Percentage missing values: 0.0
# Number of unique values: 2
# Unique values: ['No' 'Yes']
#
# Column: AUTOMOBILE
# Percentage missing values: 0.0
# Number of unique values: 2
# Unique values: ['Yes' 'No']
#
# Column: MOTORCYCLE
# Percentage missing values: 0.0
# Number of unique values: 2
# Unique values: ['No' 'Yes']
#
# Column: TRUCK
# Percentage missing values: 0.0
# Number of unique values: 2
# Unique values: ['No' 'Yes']
#
# Column: TRSN_CITY_VEH
# Percentage missing values: 0.0
# Number of unique values: 2
# Unique values: ['No' 'Yes']
#
# Column: EMERG_VEH
# Percentage missing values: 0.0
# Number of unique values: 2
# Unique values: ['No' 'Yes']
#
# Column: PASSENGER
# Percentage missing values: 0.0
# Number of unique values: 2
# Unique values: ['No' 'Yes']
#
# Column: SPEEDING
# Percentage missing values: 0.0
# Number of unique values: 2
# Unique values: ['No' 'Yes']
#
# Column: AG_DRIV
# Percentage missing values: 0.0
# Number of unique values: 2
# Unique values: ['Yes' 'No']
#
# Column: REDLIGHT
# Percentage missing values: 0.0
# Number of unique values: 2
# Unique values: ['No' 'Yes']
#
# Column: ALCOHOL
# Percentage missing values: 0.0
# Number of unique values: 2
# Unique values: ['No' 'Yes']
#
# Column: DISABILITY
# Percentage missing values: 0.0
# Number of unique values: 2
# Unique values: ['No' 'Yes']
#
# ----------------------------------------------------------------------------------------------------
# Binary column head:
#   PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK TRSN_CITY_VEH EMERG_VEH  \
# 0        Yes      No        Yes         No    No            No        No
# 1        Yes      No        Yes         No    No            No        No
# 2         No      No        Yes        Yes    No            No        No
# 3         No      No        Yes         No    No            No        No
# 4         No      No        Yes        Yes    No            No        No
#
#   PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL DISABILITY
# 0        No       No     Yes       No      No         No
# 1        No       No     Yes       No      No         No
# 2        No       No     Yes      Yes      No         No
# 3       Yes      Yes     Yes       No     Yes         No
# 4        No       No     Yes      Yes      No         No

# %% [markdown]
# <h3 style="color:maroon;">Drop columns with more than 80% missing values</h3>

# %%
# Drop columns with more than 80% missing values
threshold = 0.2 * len(df)
df = df.dropna(axis=1, thresh=threshold)

# %% [markdown]
# <h3 style="color:maroon;">Check dataframe after dropping these columns</h3>

# %%
print(Colors.MAUVE + 'Properties of dataframe:' +  Colors.END)
df_info(df)
# Out:
# Properties of dataframe:
# Shape of dataframe:
# (18189, 47)
# ACCLASS             0.000000
# IMPACTYPE           0.021991
# INVTYPE             0.087965
# INVAGE              0.000000
# INJURY              8.857001
# INITDIR            27.769531
# VEHTYPE            17.735994
# MANOEUVER          42.107867
# DRIVACT            49.194568
# DRIVCOND           49.211062
# PEDESTRIAN          0.000000
# CYCLIST             0.000000
# AUTOMOBILE          0.000000
# MOTORCYCLE          0.000000
# TRUCK               0.000000
# TRSN_CITY_VEH       0.000000
# EMERG_VEH           0.000000
# PASSENGER           0.000000
# SPEEDING            0.000000
# AG_DRIV             0.000000
# REDLIGHT            0.000000
# ALCOHOL             0.000000
# DISABILITY          0.000000
# HOOD_158            0.000000
# NEIGHBOURHOOD_158   0.000000
# HOOD_140            0.000000
# NEIGHBOURHOOD_140   0.000000
# DIVISION            0.000000

# %% [markdown]
# <div style="background-color: rgba(120,120,200,0.25); padding: 10px;">
#     <h5>Analysis of binary columns<br></h5>
#     <body>
#         <ul>
#             <li>The number of fields in the dataframe has been reduced to 47.</li>
#         </ul>
#     </body>
# </div>

# %% [markdown]
# <h3 style="color:maroon;">Generate weekday, day and month from date-time column</h3>

# %%
#Verify columns with object data type & extract features: weekday, day, month. Finally Drop Date

df['DATE'] = pd.to_datetime(df['DATE'])

df['WEEKDAY'] = df['DATE'].dt.day_name()
df['DAY'] = df['DATE'].dt.day
df['MONTH'] = df['DATE'].dt.month_name()

df.drop(columns=['DATE'], inplace=True)

# %%
print(Colors.MAUVE + 'Properties of weekday, day and month columns:' +  Colors.END)
column_info(df, ['WEEKDAY', 'DAY', 'MONTH'])
# Out:
# Properties of weekday, day and month columns:
# Column: WEEKDAY
# Percentage missing values: 0.0
# Number of unique values: 7
# Unique values: ['Saturday' 'Sunday' 'Wednesday' 'Thursday' 'Friday' 'Tuesday' 'Monday']
#
# Column: DAY
# Percentage missing values: 0.0
# Number of unique values: 31
# Unique values: [11  1 12 25 28 15 29 30  4  5  7  8  9 10 13 14 16 17 18  6  2  3 19 20
#  21 23 24 26 27 22 31]
#
# Column: MONTH
# Percentage missing values: 0.0
# Number of unique values: 12
# Unique values: ['March' 'January' 'June' 'July' 'August' 'May' 'February' 'April'
#  'September' 'October' 'November' 'December']

# %% [markdown]
# <h3 style="color:maroon;">Binarize target column (<b>ACCLASS</b>)</h3>

# %%
# Target Column exploration
print(Colors.MAUVE + 'ACCLASS before cleaning:' +  Colors.END)
column_info(df, ['ACCLASS'])
print("")

print(Colors.MAUVE + 'ACCLASS counts before cleaning:' +  Colors.END)
class_counts = df['ACCLASS'].value_counts()
print(class_counts)
print("")

# change the "Property Damage Only" class in the target ACCLASS to be combined with "Non-Fatal Injury"
df.loc[df['ACCLASS'] == 'Property Damage Only', 'ACCLASS'] = 'Non-Fatal Injury'

# Recount the number of instances in each class
print(Colors.MAUVE + 'ACCLASS after cleaning:' +  Colors.END)
column_info(df, ['ACCLASS'])
print("")

print(Colors.MAUVE + 'ACCLASS counts after cleaning:' +  Colors.END)
class_counts = df['ACCLASS'].value_counts()
print(class_counts)
# Out:
# ACCLASS before cleaning:
# Column: ACCLASS
# Percentage missing values: 0.0
# Number of unique values: 3
# Unique values: ['Fatal' 'Non-Fatal Injury' 'Property Damage Only']
#
#
# ACCLASS counts before cleaning:
# Non-Fatal Injury        15599
# Fatal                    2573
# Property Damage Only       17
# Name: ACCLASS, dtype: int64
#
# ACCLASS after cleaning:
# Column: ACCLASS
# Percentage missing values: 0.0
# Number of unique values: 2
# Unique values: ['Fatal' 'Non-Fatal Injury']
#
#
# ACCLASS counts after cleaning:
# Non-Fatal Injury    15616
# Fatal                2573
# Name: ACCLASS, dtype: int64

# %% [markdown]
# <h3 style="color:maroon;">Make a correlation matrix of numerical features</h3>

# %%
categorical_columns = df.select_dtypes(exclude='number').columns
numeric_df = df.drop(columns=categorical_columns)
correlation_matrix = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(15, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.1g', alpha=0.90)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# <div style="background-color: rgba(120,120,200,0.25); padding: 10px;">
#     <h5>Analysis of correlation matrix<br></h5>
#     <body>
#         <ul>
#             <li><b>X</b> has a correlation of 1 with <b>Longitude</b>.</li>
#             <li><b>Y</b> has a correlation of 1 with <b>Latitude</b>.</li>
#             <li>This indicaties that <b>X</b> and <b>Y</b> are duplicates of <b>Longitude</b> and <b> Latitude</b>, respectively.</li>
#             <li>This analysis is confirmed by the KSI documentation.</li>
#             <li>We, therefore, drop <b>X</b> and <b>Y</b>.</li>
#         </ul>
#     </body>
# </div>

# %% [markdown]
# <h3 style="color:maroon;">Drop X and Y</h3>

# %%
# Dropping duplicate columns X and Y column
print(Colors.MAUVE + 'Shape of dataframe before dropping X and Y:' +  Colors.END)
print(df.shape)

columns_to_drop = ['X', 'Y']
df = df.drop(columns=columns_to_drop, axis=1)

print(Colors.MAUVE + 'Shape of dataframe after dropping X and Y:' +  Colors.END)
print(df.shape)
# Out:
# Shape of dataframe before dropping X and Y:
# (18189, 49)
# Shape of dataframe after dropping X and Y:
# (18189, 47)

# %% [markdown]
# <h3 style="color:maroon;">Inspecting <b>neighbourhood</b> columns with similar names</h3>

# %%
print(Colors.MAUVE + 'Column names:' +  Colors.END)
print(list(column for column in df.columns))

print('\n' + Colors.RED + '-'*100 + Colors.END + '\n')

cols_to_inspect = ['NEIGHBOURHOOD_158','HOOD_158','NEIGHBOURHOOD_140','HOOD_140']

print(Colors.MAUVE + 'Inspection of similar columns:' +  Colors.END)
df[cols_to_inspect].head(20)
# Out:
# Column names:
# ['ACCNUM', 'YEAR', 'TIME', 'STREET1', 'STREET2', 'ROAD_CLASS', 'DISTRICT', 'WARDNUM', 'LATITUDE', 'LONGITUDE', 'LOCCOORD', 'ACCLOC', 'TRAFFCTL', 'VISIBILITY', 'LIGHT', 'RDSFCOND', 'ACCLASS', 'IMPACTYPE', 'INVTYPE', 'INVAGE', 'INJURY', 'INITDIR', 'VEHTYPE', 'MANOEUVER', 'DRIVACT', 'DRIVCOND', 'PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE', 'TRUCK', 'TRSN_CITY_VEH', 'EMERG_VEH', 'PASSENGER', 'SPEEDING', 'AG_DRIV', 'REDLIGHT', 'ALCOHOL', 'DISABILITY', 'HOOD_158', 'NEIGHBOURHOOD_158', 'HOOD_140', 'NEIGHBOURHOOD_140', 'DIVISION', 'WEEKDAY', 'DAY', 'MONTH']
#
# ----------------------------------------------------------------------------------------------------
#
# Inspection of similar columns:
#                 NEIGHBOURHOOD_158 HOOD_158                  NEIGHBOURHOOD_140  \
# 0                 High Park North       88               High Park North (88)
# 1                 High Park North       88               High Park North (88)
# 2                    Malvern East      146                      Malvern (132)
# 3                Woodbine-Lumsden       60              Woodbine-Lumsden (60)
# 4                    Malvern East      146                      Malvern (132)
# 5                    Kennedy Park      124                Eglinton East (138)
# 6                Woodbine-Lumsden       60              Woodbine-Lumsden (60)
# 7                Woodbine-Lumsden       60              Woodbine-Lumsden (60)
# 8                    Kennedy Park      124                Eglinton East (138)
# 9                    Kennedy Park      124                Eglinton East (138)
# 10               Woodbine-Lumsden       60              Woodbine-Lumsden (60)
# 11               Woodbine-Lumsden       60              Woodbine-Lumsden (60)
# 12              Trinity-Bellwoods       81             Trinity-Bellwoods (81)
# 13             Princess-Rosethorn       10            Princess-Rosethorn (10)
# 14               Woodbine-Lumsden       60              Woodbine-Lumsden (60)
# 15              Trinity-Bellwoods       81             Trinity-Bellwoods (81)
# 16               Wexford/Maryvale      119             Wexford/Maryvale (119)
# 17               Woodbine-Lumsden       60              Woodbine-Lumsden (60)
# 18  Kingsview Village-The Westway        6  Kingsview Village-The Westway (6)
# 19               Wexford/Maryvale      119             Wexford/Maryvale (119)
#
#    HOOD_140
# 0        88
# 1        88
# 2       132
# 3        60
# 4       132
# 5       138
# 6        60
# 7        60
# 8       138
# 9       138
# 10       60
# 11       60
# 12       81
# 13       10
# 14       60
# 15       81
# 16      119
# 17       60
# 18        6
# 19      119

# %% [markdown]
# <div style="background-color: rgba(120,120,200,0.25); padding: 10px;">
#     <h5>Analysis of neighbourhood columns<br></h5>
#     <body>
#         <ul>
#             <li>The neighbourhood columns appear to follow different conventions to name the same thing.</li>
#             <li>The values across the different neighbourhood columns are similar.</li>
#             <li>We, therefore, drop <b>NEIGHBOURHOOD_140</b> and <b>HOOD_140</b> as they are nearly identical to <b>NEIGHBOURHOOD_158</b> and <b>HOOD_158</b></li>
#         </ul>
#     </body>
# </div>

# %% [markdown]
# <h3 style="color:maroon;">Dropping <b>NEIGHBOURHOOD_140</b> and <b>HOOD_140</b>. </h3>

# %%
print(Colors.MAUVE + 'Shape of dataframe before dropping the columns:' +  Colors.END)
print(df.shape)

df.drop(columns=['NEIGHBOURHOOD_140','HOOD_140'],inplace=True)

print(Colors.MAUVE + 'Shape of dataframe after dropping the columns:' +  Colors.END)
print(df.shape)
# Out:
# Shape of dataframe before dropping the columns:
# (18189, 47)
# Shape of dataframe after dropping the columns:
# (18189, 45)

# %% [markdown]
# <h3 style="color:maroon;">Summary of dataframe upto this point.</h3>

# %%
df_info(df)
# Out:
# Shape of dataframe:
# (18189, 45)
#                       Type  # IsNull  # NotNull  # Total  # Unique   % Unique  \
# ACCNUM             float64      4930      13259    18189      4627  25.438452
# YEAR                 int64         0      18189    18189        17   0.093463
# TIME                 int64         0      18189    18189      1329   7.306614
# STREET1             object         0      18189    18189      1856  10.203969
# STREET2             object      1684      16505    18189      2702  14.855132
# ROAD_CLASS          object       376      17813    18189        10   0.054978
# DISTRICT            object       105      18084    18189         5   0.027489
# WARDNUM            float64       859      17330    18189        71   0.390346
# LATITUDE           float64         0      18189    18189      4498  24.729232
# LONGITUDE          float64         0      18189    18189      4935  27.131783
# LOCCOORD            object        95      18094    18189         7   0.038485
# ACCLOC              object      5450      12739    18189         9   0.049480
# TRAFFCTL            object        34      18155    18189        10   0.054978
# VISIBILITY          object        20      18169    18189         8   0.043983
# LIGHT               object         0      18189    18189         9   0.049480
# RDSFCOND            object        25      18164    18189         9   0.049480
# ACCLASS             object         0      18189    18189         2   0.010996
# IMPACTYPE           object         4      18185    18189        10   0.054978
# INVTYPE             object        16      18173    18189        19   0.104459
# INVAGE              object         0      18189    18189        21   0.115454
# INJURY              object      1611      16578    18189         5   0.027489
# INITDIR             object      5051      13138    18189         5   0.027489
# VEHTYPE             object      3226      14963    18189        31   0.170433
# MANOEUVER           object      7659      10530    18189        16   0.087965
# DRIVACT             object      8948       9241    18189        13   0.071472
# DRIVCOND            object      8951       9238    18189        10   0.054978
# PEDESTRIAN          object         0      18189    18189         2   0.010996
# CYCLIST             object         0      18189    18189         2   0.010996
# AUTOMOBILE          object         0      18189    18189         2   0.010996
# MOTORCYCLE          object         0      18189    18189         2   0.010996
# TRUCK               object         0      18189    18189         2   0.010996
# TRSN_CITY_VEH       object         0      18189    18189         2   0.010996
# EMERG_VEH           object         0      18189    18189         2   0.010996
# PASSENGER           object         0      18189    18189         2   0.010996
# SPEEDING            object         0      18189    18189         2   0.010996
# AG_DRIV             object         0      18189    18189         2   0.010996
# REDLIGHT            object         0      18189    18189         2   0.010996
# ALCOHOL             object         0      18189    18189         2   0.010996
# DISABILITY          object         0      18189    18189         2   0.010996
# HOOD_158            object         0      18189    18189       159   0.874155
# NEIGHBOURHOOD_158   object         0      18189    18189       159   0.874155
# DIVISION            object         0      18189    18189        17   0.093463
# WEEKDAY             object         0      18189    18189         7   0.038485
# DAY                  int64         0      18189    18189        31   0.170433
# MONTH               object         0      18189    18189        12   0.065974
#
#                    % Missing
# ACCNUM             27.104294
# YEAR                0.000000
# TIME                0.000000
# STREET1             0.000000
# STREET2             9.258343
# ROAD_CLASS          2.067183
# DISTRICT            0.577272
# WARDNUM             4.722635
# LATITUDE            0.000000
# LONGITUDE           0.000000
# LOCCOORD            0.522294
# ACCLOC             29.963165
# TRAFFCTL            0.186926
# VISIBILITY          0.109957
# LIGHT               0.000000
# RDSFCOND            0.137446
# ACCLASS             0.000000
# IMPACTYPE           0.021991
# INVTYPE             0.087965
# INVAGE              0.000000
# INJURY              8.857001
# INITDIR            27.769531
# VEHTYPE            17.735994
# MANOEUVER          42.107867
# DRIVACT            49.194568
# DRIVCOND           49.211062
# PEDESTRIAN          0.000000
# CYCLIST             0.000000
# AUTOMOBILE          0.000000
# MOTORCYCLE          0.000000
# TRUCK               0.000000
# TRSN_CITY_VEH       0.000000
# EMERG_VEH           0.000000
# PASSENGER           0.000000
# SPEEDING            0.000000
# AG_DRIV             0.000000
# REDLIGHT            0.000000
# ALCOHOL             0.000000
# DISABILITY          0.000000
# HOOD_158            0.000000
# NEIGHBOURHOOD_158   0.000000
# DIVISION            0.000000
# WEEKDAY             0.000000
# DAY                 0.000000
# MONTH               0.000000

# %% [markdown]
# <div style="background-color: #FFD1DC; color: black; padding: 10px;">
#     <h4 style="text-align: center;"><b>GRAPHICAL DATA EXPLORATION</b></h4>
# </div>

# %% [markdown]
# <h3 style="color:maroon;">Separate categorical variables.</h3>

# %%
# Make a dataframe containing only categorical values
categorical_columns = df.select_dtypes(exclude='number').columns
categorical_df = df[categorical_columns].copy()

print(Colors.MAUVE + 'Describe categorical features:' +  Colors.END)
df_info(categorical_df)
# Out:
# Describe categorical features:
# Shape of dataframe:
# (18189, 38)
#                      Type  # IsNull  # NotNull  # Total  # Unique   % Unique  \
# STREET1            object         0      18189    18189      1856  10.203969
# STREET2            object      1684      16505    18189      2702  14.855132
# ROAD_CLASS         object       376      17813    18189        10   0.054978
# DISTRICT           object       105      18084    18189         5   0.027489
# LOCCOORD           object        95      18094    18189         7   0.038485
# ACCLOC             object      5450      12739    18189         9   0.049480
# TRAFFCTL           object        34      18155    18189        10   0.054978
# VISIBILITY         object        20      18169    18189         8   0.043983
# LIGHT              object         0      18189    18189         9   0.049480
# RDSFCOND           object        25      18164    18189         9   0.049480
# ACCLASS            object         0      18189    18189         2   0.010996
# IMPACTYPE          object         4      18185    18189        10   0.054978
# INVTYPE            object        16      18173    18189        19   0.104459
# INVAGE             object         0      18189    18189        21   0.115454
# INJURY             object      1611      16578    18189         5   0.027489
# INITDIR            object      5051      13138    18189         5   0.027489
# VEHTYPE            object      3226      14963    18189        31   0.170433
# MANOEUVER          object      7659      10530    18189        16   0.087965
# DRIVACT            object      8948       9241    18189        13   0.071472
# DRIVCOND           object      8951       9238    18189        10   0.054978
# PEDESTRIAN         object         0      18189    18189         2   0.010996
# CYCLIST            object         0      18189    18189         2   0.010996
# AUTOMOBILE         object         0      18189    18189         2   0.010996
# MOTORCYCLE         object         0      18189    18189         2   0.010996
# TRUCK              object         0      18189    18189         2   0.010996
# TRSN_CITY_VEH      object         0      18189    18189         2   0.010996
# EMERG_VEH          object         0      18189    18189         2   0.010996
# PASSENGER          object         0      18189    18189         2   0.010996
# SPEEDING           object         0      18189    18189         2   0.010996
# AG_DRIV            object         0      18189    18189         2   0.010996
# REDLIGHT           object         0      18189    18189         2   0.010996
# ALCOHOL            object         0      18189    18189         2   0.010996
# DISABILITY         object         0      18189    18189         2   0.010996
# HOOD_158           object         0      18189    18189       159   0.874155
# NEIGHBOURHOOD_158  object         0      18189    18189       159   0.874155
# DIVISION           object         0      18189    18189        17   0.093463
# WEEKDAY            object         0      18189    18189         7   0.038485
# MONTH              object         0      18189    18189        12   0.065974
#
#                    % Missing
# STREET1             0.000000
# STREET2             9.258343
# ROAD_CLASS          2.067183
# DISTRICT            0.577272
# LOCCOORD            0.522294
# ACCLOC             29.963165
# TRAFFCTL            0.186926
# VISIBILITY          0.109957
# LIGHT               0.000000
# RDSFCOND            0.137446
# ACCLASS             0.000000
# IMPACTYPE           0.021991
# INVTYPE             0.087965
# INVAGE              0.000000
# INJURY              8.857001
# INITDIR            27.769531
# VEHTYPE            17.735994
# MANOEUVER          42.107867
# DRIVACT            49.194568
# DRIVCOND           49.211062
# PEDESTRIAN          0.000000
# CYCLIST             0.000000
# AUTOMOBILE          0.000000
# MOTORCYCLE          0.000000
# TRUCK               0.000000
# TRSN_CITY_VEH       0.000000
# EMERG_VEH           0.000000
# PASSENGER           0.000000
# SPEEDING            0.000000
# AG_DRIV             0.000000
# REDLIGHT            0.000000
# ALCOHOL             0.000000
# DISABILITY          0.000000
# HOOD_158            0.000000
# NEIGHBOURHOOD_158   0.000000
# DIVISION            0.000000
# WEEKDAY             0.000000
# MONTH               0.000000

# %% [markdown]
# <h3 style="color:maroon;">Plot number of fatal and non-fatal accidents for each category of the categorical columns. </h3>

# %%
# drop street 1 and 2, initdir, warnum, divion, injury
# make time on houry basis

colors = {'Fatal':'#ff7f7f', 'Non-Fatal Injury': '#7fbf7f'}
for column in df.columns:
    print(column)
    if df[column].nunique() < 32:
        # df[column].value_counts().plot(kind='barh
        sns.countplot(y=df[column], hue=df['ACCLASS'], data=df, palette=colors, alpha=0.9)
        plt.show()
# Out:
# ACCNUM
# YEAR
# TIME
# STREET1
# STREET2
# ROAD_CLASS
# DISTRICT
# WARDNUM
# LATITUDE
# LONGITUDE
# LOCCOORD
# ACCLOC
# TRAFFCTL
# VISIBILITY
# LIGHT
# RDSFCOND
# ACCLASS
# IMPACTYPE
# INVTYPE
# INVAGE
# INJURY
# INITDIR
# VEHTYPE
# MANOEUVER
# DRIVACT
# DRIVCOND
# PEDESTRIAN
# CYCLIST
# AUTOMOBILE
# MOTORCYCLE
# TRUCK
# TRSN_CITY_VEH
# EMERG_VEH
# PASSENGER
# SPEEDING
# AG_DRIV
# REDLIGHT
# ALCOHOL
# DISABILITY
# HOOD_158
# NEIGHBOURHOOD_158
# DIVISION
# WEEKDAY
# DAY
# MONTH

# %% [markdown]
# <div style="background-color: rgba(120,120,200,0.25); padding: 10px;">
#     <h5>Analysis of bar graphs<br></h5>
#     <body>
#         <ul>
#             <li>There are much more non-fatal accidents than fatal accidents. The data set is imbalanced.</li>
#             <li>Generally, both fatal and non-fatal accidents show similar trends in each category.</li>
#             <li>It is difficult to say, by inspection, if any of the categorical variables influence the target variable.</li>
#         </ul>
#     </body>
# </div>

# %% [markdown]
# <div style="background-color: #FFD1DC; color: black; padding: 10px;">
#     <h4 style="text-align: center;"><b>CHI SQUARE TESTS</b></h4>
# </div>

# %% [markdown]
# <h3 style="color:maroon;">Calculate chi square values for the categorical columns. </h3>

# %%
# Perform chisquare test

# Null hyp.: There is no relationship between the feature and target variable
# Alt. hyp.: There is a relationship between the feature and target variable
# For p-values smaller than significance level null hypotheses is rejected

SIGNIFICANCE_LEVEL = 0.05

for column in categorical_df.drop(columns=['ACCLASS']).columns:
    contingency_table = pd.crosstab(categorical_df[column], categorical_df['ACCLASS'])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    print("Chi-square test for " + Colors.BLUE + f"{column}:" + Colors.END)
    print(f"Chi2 value: {chi2}")
    print(f"P-value: {p}")
    
    if p < SIGNIFICANCE_LEVEL:
        print(Colors.GREEN +"Significant association with the target variable"+Colors.END)
    else:
        print(Colors.RED+"No significant association with the target variable"+Colors.END)
    
    print("")
# Out:
# Chi-square test for STREET1:
# Chi2 value: 4711.607391548585
# P-value: 1.2593555522597227e-247
# Significant association with the target variable
#
# Chi-square test for STREET2:
# Chi2 value: 7744.793575391576
# P-value: 0.0
# Significant association with the target variable
#
# Chi-square test for ROAD_CLASS:
# Chi2 value: 34.43738802374151
# P-value: 7.484944908201882e-05
# Significant association with the target variable
#
# Chi-square test for DISTRICT:
# Chi2 value: 135.80550190840825
# P-value: 2.2307274735986526e-28
# Significant association with the target variable
#
# Chi-square test for LOCCOORD:
# Chi2 value: 33.10624710309398
# P-value: 1.000358941705517e-05
# Significant association with the target variable
#
# Chi-square test for ACCLOC:
# Chi2 value: 106.17839070900052
# P-value: 2.318922895749838e-19
# Significant association with the target variable
#
# Chi-square test for TRAFFCTL:
# Chi2 value: 70.57348415919755
# P-value: 1.1752145181571326e-11
# Significant association with the target variable
#
# Chi-square test for VISIBILITY:
# Chi2 value: 60.940019533604655
# P-value: 9.795776648489712e-11
# Significant association with the target variable
#
# Chi-square test for LIGHT:
# Chi2 value: 74.29391666043252
# P-value: 6.829981078564804e-13
# Significant association with the target variable
#
# Chi-square test for RDSFCOND:
# Chi2 value: 59.88542024141859
# P-value: 4.908602887881684e-10
# Significant association with the target variable
#
# Chi-square test for IMPACTYPE:
# Chi2 value: 360.8887308483362
# P-value: 2.9786795442808124e-72
# Significant association with the target variable
#
# Chi-square test for INVTYPE:
# Chi2 value: 170.73811824789524
# P-value: 6.482478867109732e-27
# Significant association with the target variable
#
# Chi-square test for INVAGE:
# Chi2 value: 206.30691590886954
# P-value: 6.33621965773659e-33
# Significant association with the target variable
#
# Chi-square test for INJURY:
# Chi2 value: 6562.545752037962
# P-value: 0.0
# Significant association with the target variable
#
# Chi-square test for INITDIR:
# Chi2 value: 19.353146896047097
# P-value: 0.0006698066266542313
# Significant association with the target variable
#
# Chi-square test for VEHTYPE:
# Chi2 value: 204.74456381397616
# P-value: 6.3905158026653395e-28
# Significant association with the target variable
#
# Chi-square test for MANOEUVER:
# Chi2 value: 89.87064373716552
# P-value: 1.0485330216212684e-12
# Significant association with the target variable
#
# Chi-square test for DRIVACT:
# Chi2 value: 146.25477335356354
# P-value: 3.2561415572018534e-25
# Significant association with the target variable
#
# Chi-square test for DRIVCOND:
# Chi2 value: 237.96027132061226
# P-value: 3.4590366996498392e-46
# Significant association with the target variable
#
# Chi-square test for PEDESTRIAN:
# Chi2 value: 171.36976490319663
# P-value: 3.7153781643563925e-39
# Significant association with the target variable
#
# Chi-square test for CYCLIST:
# Chi2 value: 100.23390199684486
# P-value: 1.354215439356364e-23
# Significant association with the target variable
#
# Chi-square test for AUTOMOBILE:
# Chi2 value: 103.25630043532242
# P-value: 2.9447763976776515e-24
# Significant association with the target variable
#
# Chi-square test for MOTORCYCLE:
# Chi2 value: 0.20433797348619465
# P-value: 0.6512419100908078
# No significant association with the target variable
#
# Chi-square test for TRUCK:
# Chi2 value: 230.79506139749375
# P-value: 3.999025987127256e-52
# Significant association with the target variable
#
# Chi-square test for TRSN_CITY_VEH:
# Chi2 value: 48.65792439364956
# P-value: 3.0473451061081197e-12
# Significant association with the target variable
#
# Chi-square test for EMERG_VEH:
# Chi2 value: 2.463761513820831
# P-value: 0.11649949636726994
# No significant association with the target variable
#
# Chi-square test for PASSENGER:
# Chi2 value: 0.03064022447306715
# P-value: 0.8610454585836846
# No significant association with the target variable
#
# Chi-square test for SPEEDING:
# Chi2 value: 155.38847364795245
# P-value: 1.1515983618923305e-35
# Significant association with the target variable
#
# Chi-square test for AG_DRIV:
# Chi2 value: 16.26640444926357
# P-value: 5.503106016669598e-05
# Significant association with the target variable
#
# Chi-square test for REDLIGHT:
# Chi2 value: 0.0731514286861593
# P-value: 0.7868023798726097
# No significant association with the target variable
#
# Chi-square test for ALCOHOL:
# Chi2 value: 12.648695293027439
# P-value: 0.0003758278686302286
# Significant association with the target variable
#
# Chi-square test for DISABILITY:
# Chi2 value: 0.6797879017954794
# P-value: 0.40965976893275935
# No significant association with the target variable
#
# Chi-square test for HOOD_158:
# Chi2 value: 766.463364364873
# P-value: 1.3153623911454498e-80
# Significant association with the target variable
#
# Chi-square test for NEIGHBOURHOOD_158:
# Chi2 value: 766.463364364873
# P-value: 1.3153623911454498e-80
# Significant association with the target variable
#
# Chi-square test for DIVISION:
# Chi2 value: 186.03605212031806
# P-value: 5.174885758905911e-31
# Significant association with the target variable
#
# Chi-square test for WEEKDAY:
# Chi2 value: 28.025203152857586
# P-value: 9.294137144876846e-05
# Significant association with the target variable
#
# Chi-square test for MONTH:
# Chi2 value: 62.52997041769851
# P-value: 3.130938543713968e-09
# Significant association with the target variable

# %% [markdown]
# <div style="background-color: rgba(120,120,200,0.25); padding: 10px;">
#     <h5>Analysis of chi2 data<br></h5>
#     <body>
#         Based on the chi2 data we can consider dropping the following columns:
#         <ul>
#             <li><b>MOTORCYCLE<b></li>
#             <li><b>EMERG_VEH<b></li>
#             <li><b>PASSENGER<b></li>
#             <li><b>REDLIGHT<b></li>
#             <li><b>DISABILITY<b></li>
#         </ul>
#     </body>
# </div>

# %% [markdown]
# <h3 style="color:maroon;">Drop columns based on p values. </h3>

# %%
columns_to_drop = ['MOTORCYCLE','EMERG_VEH','PASSENGER','REDLIGHT','DISABILITY']
df.drop(columns=columns_to_drop, inplace=True)

# %%
print(Colors.MAUVE + 'Df info after dropping columns as per p-values:' +  Colors.END)
df_info(df)
# Out:
# Df info after dropping columns as per p-values:
# Shape of dataframe:
# (18189, 40)
#                       Type  # IsNull  # NotNull  # Total  # Unique   % Unique  \
# ACCNUM             float64      4930      13259    18189      4627  25.438452
# YEAR                 int64         0      18189    18189        17   0.093463
# TIME                 int64         0      18189    18189      1329   7.306614
# STREET1             object         0      18189    18189      1856  10.203969
# STREET2             object      1684      16505    18189      2702  14.855132
# ROAD_CLASS          object       376      17813    18189        10   0.054978
# DISTRICT            object       105      18084    18189         5   0.027489
# WARDNUM            float64       859      17330    18189        71   0.390346
# LATITUDE           float64         0      18189    18189      4498  24.729232
# LONGITUDE          float64         0      18189    18189      4935  27.131783
# LOCCOORD            object        95      18094    18189         7   0.038485
# ACCLOC              object      5450      12739    18189         9   0.049480
# TRAFFCTL            object        34      18155    18189        10   0.054978
# VISIBILITY          object        20      18169    18189         8   0.043983
# LIGHT               object         0      18189    18189         9   0.049480
# RDSFCOND            object        25      18164    18189         9   0.049480
# ACCLASS             object         0      18189    18189         2   0.010996
# IMPACTYPE           object         4      18185    18189        10   0.054978
# INVTYPE             object        16      18173    18189        19   0.104459
# INVAGE              object         0      18189    18189        21   0.115454
# INJURY              object      1611      16578    18189         5   0.027489
# INITDIR             object      5051      13138    18189         5   0.027489
# VEHTYPE             object      3226      14963    18189        31   0.170433
# MANOEUVER           object      7659      10530    18189        16   0.087965
# DRIVACT             object      8948       9241    18189        13   0.071472
# DRIVCOND            object      8951       9238    18189        10   0.054978
# PEDESTRIAN          object         0      18189    18189         2   0.010996
# CYCLIST             object         0      18189    18189         2   0.010996
# AUTOMOBILE          object         0      18189    18189         2   0.010996
# TRUCK               object         0      18189    18189         2   0.010996
# TRSN_CITY_VEH       object         0      18189    18189         2   0.010996
# SPEEDING            object         0      18189    18189         2   0.010996
# AG_DRIV             object         0      18189    18189         2   0.010996
# ALCOHOL             object         0      18189    18189         2   0.010996
# HOOD_158            object         0      18189    18189       159   0.874155
# NEIGHBOURHOOD_158   object         0      18189    18189       159   0.874155
# DIVISION            object         0      18189    18189        17   0.093463
# WEEKDAY             object         0      18189    18189         7   0.038485
# DAY                  int64         0      18189    18189        31   0.170433
# MONTH               object         0      18189    18189        12   0.065974
#
#                    % Missing
# ACCNUM             27.104294
# YEAR                0.000000
# TIME                0.000000
# STREET1             0.000000
# STREET2             9.258343
# ROAD_CLASS          2.067183
# DISTRICT            0.577272
# WARDNUM             4.722635
# 5       No      No     Yes      124      Kennedy Park      D41    Sunday  12
# 6      Yes     Yes     Yes       60  Woodbine-Lumsden      D55    Sunday   1
# 7      Yes     Yes     Yes       60  Woodbine-Lumsden      D55    Sunday   1
# 8       No      No     Yes      124      Kennedy Park      D41    Sunday  12
# 9       No      No     Yes      124      Kennedy Park      D41    Sunday  12
#
#      MONTH
# 0    March
# 1    March
# 2    March
# 3  January
# 4    March
# 5    March
# 6  January
# 7  January
# 8    March
# 9    March
#
# [10 rows x 40 columns]

# %% [markdown]
# <div style="background-color: #FFD1DC; color: black; padding: 10px;">
#     <h4 style="text-align: center;"><b>DROP FEATURES UNRELATED TO THE TARGET</b></h4>
# </div>

# %%
features_to_drop = ['INITDIR','STREET1','STREET2','WARDNUM','INJURY'] # Injury removed because it disproportionately effects prediction
df.drop(columns=features_to_drop, inplace =True)

# %%
df_info(df)
# Out:
# Shape of dataframe:
# (18189, 35)
#                       Type  # IsNull  # NotNull  # Total  # Unique   % Unique  \
# ACCNUM             float64      4930      13259    18189      4627  25.438452
# YEAR                 int64         0      18189    18189        17   0.093463
# TIME                 int64         0      18189    18189      1329   7.306614
# ROAD_CLASS          object       376      17813    18189        10   0.054978
# DISTRICT            object       105      18084    18189         5   0.027489
# LATITUDE           float64         0      18189    18189      4498  24.729232
# LONGITUDE          float64         0      18189    18189      4935  27.131783
# LOCCOORD            object        95      18094    18189         7   0.038485
# ACCLOC              object      5450      12739    18189         9   0.049480
# TRAFFCTL            object        34      18155    18189        10   0.054978
# VISIBILITY          object        20      18169    18189         8   0.043983
# LIGHT               object         0      18189    18189         9   0.049480
# RDSFCOND            object        25      18164    18189         9   0.049480
# ACCLASS             object         0      18189    18189         2   0.010996
# IMPACTYPE           object         4      18185    18189        10   0.054978
# INVTYPE             object        16      18173    18189        19   0.104459
# INVAGE              object         0      18189    18189        21   0.115454
# VEHTYPE             object      3226      14963    18189        31   0.170433
# MANOEUVER           object      7659      10530    18189        16   0.087965
# DRIVACT             object      8948       9241    18189        13   0.071472
# DRIVCOND            object      8951       9238    18189        10   0.054978
# PEDESTRIAN          object         0      18189    18189         2   0.010996
# CYCLIST             object         0      18189    18189         2   0.010996
# AUTOMOBILE          object         0      18189    18189         2   0.010996
# TRUCK               object         0      18189    18189         2   0.010996
# TRSN_CITY_VEH       object         0      18189    18189         2   0.010996
# SPEEDING            object         0      18189    18189         2   0.010996
# AG_DRIV             object         0      18189    18189         2   0.010996
# ALCOHOL             object         0      18189    18189         2   0.010996
# HOOD_158            object         0      18189    18189       159   0.874155
# NEIGHBOURHOOD_158   object         0      18189    18189       159   0.874155
# DIVISION            object         0      18189    18189        17   0.093463
# WEEKDAY             object         0      18189    18189         7   0.038485
# DAY                  int64         0      18189    18189        31   0.170433
# MONTH               object         0      18189    18189        12   0.065974
#
#                    % Missing
# ACCNUM             27.104294
# YEAR                0.000000
# TIME                0.000000
# ROAD_CLASS          2.067183
# DISTRICT            0.577272
# LATITUDE            0.000000
# LONGITUDE           0.000000
# LOCCOORD            0.522294
# ACCLOC             29.963165
# TRAFFCTL            0.186926
# VISIBILITY          0.109957
# LIGHT               0.000000
# RDSFCOND            0.137446
# ACCLASS             0.000000
# IMPACTYPE           0.021991
# INVTYPE             0.087965
# INVAGE              0.000000
# VEHTYPE            17.735994
# MANOEUVER          42.107867
# DRIVACT            49.194568
# DRIVCOND           49.211062
# PEDESTRIAN          0.000000
# CYCLIST             0.000000
# AUTOMOBILE          0.000000
# TRUCK               0.000000
# TRSN_CITY_VEH       0.000000
# SPEEDING            0.000000
# AG_DRIV             0.000000
# ALCOHOL             0.000000
# HOOD_158            0.000000
# NEIGHBOURHOOD_158   0.000000
# DIVISION            0.000000
# WEEKDAY             0.000000
# DAY                 0.000000
# MONTH               0.000000

# %% [markdown]
# <div style="background-color: #FFD1DC; color: black; padding: 10px;">
#     <h4 style="text-align: center;"><b>SPLIT DATASET INTO TRAINING AND TEST SETS</b></h4>
# </div>

# %%
#Split the dataset
from sklearn.model_selection import StratifiedShuffleSplit
from imblearn.over_sampling import SMOTE

X = df.drop(columns=['ACCLASS'])  # Features
y = df['ACCLASS']  # Target variable

# Perform SMOTE oversampling to balance the dataset
smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X, y)

# Perform stratified shuffle split on the resampled data
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in sss.split(X_res, y_res):
    X_train, X_test = X_res[train_index], X_res[test_index]
    y_train, y_test = y_res[train_index], y_res[test_index]

'''
print(Colors.MAUVE + 'Shape of training data set' + Colors.END)
print(train_set.shape)

print(Colors.MAUVE + 'Shape of testing data set' + Colors.END)
print(test_set.shape)

# Remove target so it doesn't influence the model training or evaluation
X_train = train_set.drop('ACCLASS', axis=1)
y_train = train_set['ACCLASS'].copy()

X_test = test_set.drop('ACCLASS', axis=1)
y_test = test_set['ACCLASS'].copy()
'''

print(Colors.MAUVE + 'Shape of X_train' + Colors.END)
print(X_train.shape)

print(Colors.MAUVE + 'Shape of y_train' + Colors.END)
print(y_train.shape)

print(Colors.MAUVE + 'Shape X_test' + Colors.END)
print(X_test.shape)

print(Colors.MAUVE + 'Shape of y_test' + Colors.END)
print(y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[34], line 3
#       1 #Split the dataset
#       2 from sklearn.model_selection import StratifiedShuffleSplit
# ----> 3 from imblearn.over_sampling import SMOTE
#       5 X = df.drop(columns=['ACCLASS'])  # Features
#       6 y = df['ACCLASS']  # Target variable
#
# File c:\Users\User\anaconda3\Lib\site-packages\imblearn\__init__.py:52
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import (
#      53         combine,
#      54         ensemble,
#      55         exceptions,
#      56         metrics,
#      57         over_sampling,
#      58         pipeline,
#      59         tensorflow,
#      60         under_sampling,
#      61         utils,
#      62     )
#      63     from ._version import __version__
#      64     from .base import FunctionSampler
#
# File c:\Users\User\anaconda3\Lib\site-packages\imblearn\combine\__init__.py:5
#       1 """The :mod:`imblearn.combine` provides methods which combine
#       2 over-sampling and under-sampling.
#       3 """
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       8 __all__ = ["SMOTEENN", "SMOTETomek"]
#
# File c:\Users\User\anaconda3\Lib\site-packages\imblearn\combine\_smote_enn.py:12
#       9 from sklearn.base import clone
#      10 from sklearn.utils import check_X_y
# ---> 12 from ..base import BaseSampler
#      13 from ..over_sampling import SMOTE
#      14 from ..over_sampling.base import BaseOverSampler
#
# File c:\Users\User\anaconda3\Lib\site-packages\imblearn\base.py:21
#      18 from sklearn.utils.multiclass import check_classification_targets
#      20 from .utils import check_sampling_strategy, check_target_type
# ---> 21 from .utils._param_validation import validate_parameter_constraints
#      22 from .utils._validation import ArraysTransformer
#      25 class SamplerMixin(BaseEstimator, metaclass=ABCMeta):
#
# File c:\Users\User\anaconda3\Lib\site-packages\imblearn\utils\_param_validation.py:908
#     906 from sklearn.utils._param_validation import generate_valid_param  # noqa
#     907 from sklearn.utils._param_validation import validate_parameter_constraints  # noqa
# --> 908 from sklearn.utils._param_validation import (
#     909     HasMethods,
#     910     Hidden,
#     911     Interval,
#     912     Options,
#     913     StrOptions,
#     914     _ArrayLikes,
#     915     _Booleans,
#     916     _Callables,
#     917     _CVObjects,
#     918     _InstancesOf,
#     919     _IterablesNotString,
#     920     _MissingValues,
#     921     _NoneConstraint,
#     922     _PandasNAConstraint,
#     923     _RandomStates,
#     924     _SparseMatrices,
#     925     _VerboseHelper,
#     926     make_constraint,
#     927     validate_params,
#     928 )
#
# ImportError: cannot import name '_MissingValues' from 'sklearn.utils._param_validation' (c:\Users\User\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_selector as selector

numerical_features = selector(dtype_include=np.number)(df)
categorical_features = selector(dtype_exclude=np.number)(df)

print("Numerical features:", numerical_features)
print("Categorical features:", categorical_features)

#  preprocessing steps for numerical features
numerical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')), 
    ('scaler', StandardScaler())  
])

#  preprocessing steps for categorical features
categorical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),  
    ('onehot', OneHotEncoder())  
])

# Combine preprocessing steps for both numerical and categorical features
preprocessor = ColumnTransformer([
    ('num', numerical_pipeline, numerical_features),
    ('cat', categorical_pipeline, categorical_features)
])
# Out:
# Numerical features: ['ACCNUM', 'YEAR', 'TIME', 'LATITUDE', 'LONGITUDE', 'DAY']
# Categorical features: ['ROAD_CLASS', 'DISTRICT', 'LOCCOORD', 'ACCLOC', 'TRAFFCTL', 'VISIBILITY', 'LIGHT', 'RDSFCOND', 'ACCLASS', 'IMPACTYPE', 'INVTYPE', 'INVAGE', 'VEHTYPE', 'MANOEUVER', 'DRIVACT', 'DRIVCOND', 'PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'TRUCK', 'TRSN_CITY_VEH', 'SPEEDING', 'AG_DRIV', 'ALCOHOL', 'HOOD_158', 'NEIGHBOURHOOD_158', 'DIVISION', 'WEEKDAY', 'MONTH']
